# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Preprocessing Report
#
# This notebook performs the following preprocessing steps on your audio dataset:
#
# 1.  **Mounting Google Drive**: The notebook starts by mounting your Google Drive to access the audio files stored there.
# 2.  **Installing Libraries**: The necessary library (`pydub`) for audio manipulation and `ffmpeg` for audio format conversion are installed.
# 3.  **Listing Files**: The files within the main audio dataset folder are listed to provide an overview of the raw data.
# 4.  **Splitting into 5-second clips**: Initial splitting of the audio files in `/content/drive/MyDrive/Audio Dataset CSE400` into 5-second WAV clips, organized into subfolders within a `5sec_dataset` folder.
# 5.  **Counting 5-second clips**: The total number of 5-second WAV clips generated is counted and displayed.
# 6.  **Splitting 'Normal Child' audio into 1-second clips**: Audio files from the 'Normal Child' folder are split into 1-second WAV clips, organized into subfolders within a `1sec_dataset` folder inside the 'Normal Child' directory.
# 7.  **Counting 1-second clips in 'Audio Dataset CSE400/1sec_dataset'**: The total number of 1-second WAV clips in the `1sec_dataset` folder within `Audio Dataset CSE400` is counted.
# 8.  **Verifying File Structure**: The file structure within the `1sec_dataset` folder is displayed to confirm the organization of the split audio clips.
# 9.  **Counting WAV files in parent folders**: The total number of WAV files in the main `Audio Dataset CSE400` folder and the `Normal Child` folder are counted (this likely includes the newly created 1-second and 5-second datasets within these folders).
# 10. **Correcting 'Normal Child' 1-second splitting**: The code in cell `EBa-gGf7OS39` correctly splits the 'Normal Child' audio into 1-second clips within a `1sec_dataset` subfolder inside 'Normal Child'.
# 11. **Counting 'Normal Child' 1-second clips**: The total number of 1-second WAV clips specifically within the `/content/drive/MyDrive/Normal Child/1sec_dataset` folder is confirmed.
# 12. **Creating Metadata CSV**: A `combined_metadata.csv` file is generated, listing the filepaths and corresponding labels ('autistic' or 'non_autistic') for all the 1-second WAV clips created from both the main audio dataset and the 'Normal Child' dataset.
# 13. **Verifying clip counts per label**: The number of clips for 'autistic' and 'non-autistic' labels is counted from the generated dataset structure to confirm the distribution.
# 14. **Splitting 'Audio Dataset CSE400' into 1-second clips**: The code in cell `a0IvZJfXZNb3` splits the audio files in the main `Audio Dataset CSE400` folder into 1-second WAV clips, ensuring consistency in the time duration of clips across both categories.
#
# These steps prepare the audio data for further analysis or model training by standardizing the clip length and creating a metadata file for easy access and labeling.

# %%
# !pip install pydub
# !apt install ffmpeg
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
import os

folder_path = '/content/drive/MyDrive/Audio Dataset CSE400'
files = os.listdir(folder_path)

print("Files in folder:")
for file in files:
    print(file)
# Out:
# Files in folder:
# Recording_18.m4a
# Recording_19.m4a
# Recording_16.m4a
# Recording_11.m4a
# Recording_5.m4a
# Recording_8.m4a
# Recording_14.m4a
# Recording_13.m4a
# Recording_7.m4a
# Recording_4.m4a
# Recording_10.m4a
# Recording_12.m4a
# Recording_17.m4a
# Recording_15.m4a
# Recording_9.m4a
# Recording_6.m4a
# 1sec_dataset
# 5sec_dataset

# %%
from pydub import AudioSegment
import os

input_folder = '/content/drive/MyDrive/Audio Dataset CSE400'
output_folder = os.path.join(input_folder, '5sec_dataset')
os.makedirs(output_folder, exist_ok=True)

# Loop through all .m4a files
for filename in os.listdir(input_folder):
    if filename.endswith(".m4a"):
        audio_path = os.path.join(input_folder, filename)
        audio = AudioSegment.from_file(audio_path, format="m4a")

        chunk_length_ms = 5 * 1000  # 5 seconds

        # Create a subfolder for each audio file
        base_name = os.path.splitext(filename)[0]
        file_output_folder = os.path.join(output_folder, base_name)
        os.makedirs(file_output_folder, exist_ok=True)

        # Split into 5-second chunks
        for i, chunk_start in enumerate(range(0, len(audio), chunk_length_ms)):
            chunk = audio[chunk_start:chunk_start + chunk_length_ms]
            chunk.export(f"{file_output_folder}/clip_{i:04d}.wav", format="wav")

        print(f"✅ Done splitting: {filename}")
# Out:
# ✅ Done splitting: Recording_18.m4a
# ✅ Done splitting: Recording_19.m4a
# ✅ Done splitting: Recording_16.m4a
# ✅ Done splitting: Recording_11.m4a
# ✅ Done splitting: Recording_5.m4a
# ✅ Done splitting: Recording_8.m4a
# ✅ Done splitting: Recording_14.m4a
# ✅ Done splitting: Recording_13.m4a
# ✅ Done splitting: Recording_7.m4a
# ✅ Done splitting: Recording_4.m4a
# ✅ Done splitting: Recording_10.m4a
# ✅ Done splitting: Recording_12.m4a
# ✅ Done splitting: Recording_17.m4a
# ✅ Done splitting: Recording_15.m4a
# ✅ Done splitting: Recording_9.m4a
# ✅ Done splitting: Recording_6.m4a

# %%
import os

base_folder = '/content/drive/MyDrive/Audio Dataset CSE400/5sec_dataset'
total_clips = 0

for subdir, _, files in os.walk(base_folder):
    for file in files:
        if file.endswith('.wav'):
            total_clips += 1

print(f"🎧 Total clips in dataset: {total_clips}")
# Out:
# 🎧 Total clips in dataset: 462

# %%
normal_input_folder = '/content/drive/MyDrive//Normal Child'
normal_output_base = '/content/drive/MyDrive//1sec_dataset/Normal Child'

os.makedirs(normal_output_base, exist_ok=True)

for filename in os.listdir(normal_input_folder):
    if filename.endswith(".m4a"):
        audio_path = os.path.join(normal_input_folder, filename)
        audio = AudioSegment.from_file(audio_path, format="m4a")

        base_name = os.path.splitext(filename)[0]
        output_folder = os.path.join(normal_output_base, base_name)
        os.makedirs(output_folder, exist_ok=True)

        for i, chunk_start in enumerate(range(0, len(audio), chunk_length_ms)):
            chunk = audio[chunk_start:chunk_start + chunk_length_ms]
            chunk.export(f"{output_folder}/clip_{i:04d}.wav", format="wav")

        print(f"✅ Normal child audio split: {filename}")
# Out:
# ✅ Normal child audio split: Recording_28.m4a
# ✅ Normal child audio split: Recording_23.m4a
# ✅ Normal child audio split: Recording_30.m4a
# ✅ Normal child audio split: Recording_27.m4a
# ✅ Normal child audio split: Recording_29.m4a
# ✅ Normal child audio split: Recording_26.m4a
# ✅ Normal child audio split: Recording_25.m4a
# ✅ Normal child audio split: Recording_24.m4a
# ✅ Normal child audio split: Recording_21.m4a
# ✅ Normal child audio split: Recording_22.m4a

# %%
import os

dataset_path = '/content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset'
total_clips = 0

for subdir, _, files in os.walk(dataset_path):
    for file in files:
        if file.endswith('.wav'):
            total_clips += 1

print(f"🎧 Total number of 1-second clips: {total_clips}")
# Out:
# 🎧 Total number of 1-second clips: 2284

# %%
import os

path = '/content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset'

for root, dirs, files in os.walk(path):
    print(f"📁 Folder: {root}")
    for file in files:
        print(f"    - {file}")
# Out:
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_18
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
#     - clip_0078.wav
#     - clip_0079.wav
#     - clip_0080.wav
#     - clip_0081.wav
#     - clip_0082.wav
#     - clip_0083.wav
#     - clip_0084.wav
#     - clip_0085.wav
#     - clip_0086.wav
#     - clip_0087.wav
#     - clip_0088.wav
#     - clip_0089.wav
#     - clip_0090.wav
#     - clip_0091.wav
#     - clip_0092.wav
#     - clip_0093.wav
#     - clip_0094.wav
#     - clip_0095.wav
#     - clip_0096.wav
#     - clip_0097.wav
#     - clip_0098.wav
#     - clip_0099.wav
#     - clip_0100.wav
#     - clip_0101.wav
#     - clip_0102.wav
#     - clip_0103.wav
#     - clip_0104.wav
#     - clip_0105.wav
#     - clip_0106.wav
#     - clip_0107.wav
#     - clip_0108.wav
#     - clip_0109.wav
#     - clip_0110.wav
#     - clip_0111.wav
#     - clip_0112.wav
#     - clip_0113.wav
#     - clip_0114.wav
#     - clip_0115.wav
#     - clip_0116.wav
#     - clip_0117.wav
#     - clip_0118.wav
#     - clip_0119.wav
#     - clip_0120.wav
#     - clip_0121.wav
#     - clip_0122.wav
#     - clip_0123.wav
#     - clip_0124.wav
#     - clip_0125.wav
#     - clip_0126.wav
#     - clip_0127.wav
#     - clip_0128.wav
#     - clip_0129.wav
#     - clip_0130.wav
#     - clip_0131.wav
#     - clip_0132.wav
#     - clip_0133.wav
#     - clip_0134.wav
#     - clip_0135.wav
#     - clip_0136.wav
#     - clip_0137.wav
#     - clip_0138.wav
#     - clip_0139.wav
#     - clip_0140.wav
#     - clip_0141.wav
#     - clip_0142.wav
#     - clip_0143.wav
#     - clip_0144.wav
#     - clip_0145.wav
#     - clip_0146.wav
#     - clip_0147.wav
#     - clip_0148.wav
#     - clip_0149.wav
#     - clip_0150.wav
#     - clip_0151.wav
#     - clip_0152.wav
#     - clip_0153.wav
#     - clip_0154.wav
#     - clip_0155.wav
#     - clip_0156.wav
#     - clip_0157.wav
#     - clip_0158.wav
#     - clip_0159.wav
#     - clip_0160.wav
#     - clip_0161.wav
#     - clip_0162.wav
#     - clip_0163.wav
#     - clip_0164.wav
#     - clip_0165.wav
#     - clip_0166.wav
#     - clip_0167.wav
#     - clip_0168.wav
#     - clip_0169.wav
#     - clip_0170.wav
#     - clip_0171.wav
#     - clip_0172.wav
#     - clip_0173.wav
#     - clip_0174.wav
#     - clip_0175.wav
#     - clip_0176.wav
#     - clip_0177.wav
#     - clip_0178.wav
#     - clip_0179.wav
#     - clip_0180.wav
#     - clip_0181.wav
#     - clip_0182.wav
#     - clip_0183.wav
#     - clip_0184.wav
#     - clip_0185.wav
#     - clip_0186.wav
#     - clip_0187.wav
#     - clip_0188.wav
#     - clip_0189.wav
#     - clip_0190.wav
#     - clip_0191.wav
#     - clip_0192.wav
#     - clip_0193.wav
#     - clip_0194.wav
#     - clip_0195.wav
#     - clip_0196.wav
#     - clip_0197.wav
#     - clip_0198.wav
#     - clip_0199.wav
#     - clip_0200.wav
#     - clip_0201.wav
#     - clip_0202.wav
#     - clip_0203.wav
#     - clip_0204.wav
#     - clip_0205.wav
#     - clip_0206.wav
#     - clip_0207.wav
#     - clip_0208.wav
#     - clip_0209.wav
#     - clip_0210.wav
#     - clip_0211.wav
#     - clip_0212.wav
#     - clip_0213.wav
#     - clip_0214.wav
#     - clip_0215.wav
#     - clip_0216.wav
#     - clip_0217.wav
#     - clip_0218.wav
#     - clip_0219.wav
#     - clip_0220.wav
#     - clip_0221.wav
#     - clip_0222.wav
#     - clip_0223.wav
#     - clip_0224.wav
#     - clip_0225.wav
#     - clip_0226.wav
#     - clip_0227.wav
#     - clip_0228.wav
#     - clip_0229.wav
#     - clip_0230.wav
#     - clip_0231.wav
#     - clip_0232.wav
#     - clip_0233.wav
#     - clip_0234.wav
#     - clip_0235.wav
#     - clip_0236.wav
#     - clip_0237.wav
#     - clip_0238.wav
#     - clip_0239.wav
#     - clip_0240.wav
#     - clip_0241.wav
#     - clip_0242.wav
#     - clip_0243.wav
#     - clip_0244.wav
#     - clip_0245.wav
#     - clip_0246.wav
#     - clip_0247.wav
#     - clip_0248.wav
#     - clip_0249.wav
#     - clip_0250.wav
#     - clip_0251.wav
#     - clip_0252.wav
#     - clip_0253.wav
#     - clip_0254.wav
#     - clip_0255.wav
#     - clip_0256.wav
#     - clip_0257.wav
#     - clip_0258.wav
#     - clip_0259.wav
#     - clip_0260.wav
#     - clip_0261.wav
#     - clip_0262.wav
#     - clip_0263.wav
#     - clip_0264.wav
#     - clip_0265.wav
#     - clip_0266.wav
#     - clip_0267.wav
#     - clip_0268.wav
#     - clip_0269.wav
#     - clip_0270.wav
#     - clip_0271.wav
#     - clip_0272.wav
#     - clip_0273.wav
#     - clip_0274.wav
#     - clip_0275.wav
#     - clip_0276.wav
#     - clip_0277.wav
#     - clip_0278.wav
#     - clip_0279.wav
#     - clip_0280.wav
#     - clip_0281.wav
#     - clip_0282.wav
#     - clip_0283.wav
#     - clip_0284.wav
#     - clip_0285.wav
#     - clip_0286.wav
#     - clip_0287.wav
#     - clip_0288.wav
#     - clip_0289.wav
#     - clip_0290.wav
#     - clip_0291.wav
#     - clip_0292.wav
#     - clip_0293.wav
#     - clip_0294.wav
#     - clip_0295.wav
#     - clip_0296.wav
#     - clip_0297.wav
#     - clip_0298.wav
#     - clip_0299.wav
#     - clip_0300.wav
#     - clip_0301.wav
#     - clip_0302.wav
#     - clip_0303.wav
#     - clip_0304.wav
#     - clip_0305.wav
#     - clip_0306.wav
#     - clip_0307.wav
#     - clip_0308.wav
#     - clip_0309.wav
#     - clip_0310.wav
#     - clip_0311.wav
#     - clip_0312.wav
#     - clip_0313.wav
#     - clip_0314.wav
#     - clip_0315.wav
#     - clip_0316.wav
#     - clip_0317.wav
#     - clip_0318.wav
#     - clip_0319.wav
#     - clip_0320.wav
#     - clip_0321.wav
#     - clip_0322.wav
#     - clip_0323.wav
#     - clip_0324.wav
#     - clip_0325.wav
#     - clip_0326.wav
#     - clip_0327.wav
#     - clip_0328.wav
#     - clip_0329.wav
#     - clip_0330.wav
#     - clip_0331.wav
#     - clip_0332.wav
#     - clip_0333.wav
#     - clip_0334.wav
#     - clip_0335.wav
#     - clip_0336.wav
#     - clip_0337.wav
#     - clip_0338.wav
#     - clip_0339.wav
#     - clip_0340.wav
#     - clip_0341.wav
#     - clip_0342.wav
#     - clip_0343.wav
#     - clip_0344.wav
#     - clip_0345.wav
#     - clip_0346.wav
#     - clip_0347.wav
#     - clip_0348.wav
#     - clip_0349.wav
#     - clip_0350.wav
#     - clip_0351.wav
#     - clip_0352.wav
#     - clip_0353.wav
#     - clip_0354.wav
#     - clip_0355.wav
#     - clip_0356.wav
#     - clip_0357.wav
#     - clip_0358.wav
#     - clip_0359.wav
#     - clip_0360.wav
#     - clip_0361.wav
#     - clip_0362.wav
#     - clip_0363.wav
#     - clip_0364.wav
#     - clip_0365.wav
#     - clip_0366.wav
#     - clip_0367.wav
#     - clip_0368.wav
#     - clip_0369.wav
#     - clip_0370.wav
#     - clip_0371.wav
#     - clip_0372.wav
#     - clip_0373.wav
#     - clip_0374.wav
#     - clip_0375.wav
#     - clip_0376.wav
#     - clip_0377.wav
#     - clip_0378.wav
#     - clip_0379.wav
#     - clip_0380.wav
#     - clip_0381.wav
#     - clip_0382.wav
#     - clip_0383.wav
#     - clip_0384.wav
#     - clip_0385.wav
#     - clip_0386.wav
#     - clip_0387.wav
#     - clip_0388.wav
#     - clip_0389.wav
#     - clip_0390.wav
#     - clip_0391.wav
#     - clip_0392.wav
#     - clip_0393.wav
#     - clip_0394.wav
#     - clip_0395.wav
#     - clip_0396.wav
#     - clip_0397.wav
#     - clip_0398.wav
#     - clip_0399.wav
#     - clip_0400.wav
#     - clip_0401.wav
#     - clip_0402.wav
#     - clip_0403.wav
#     - clip_0404.wav
#     - clip_0405.wav
#     - clip_0406.wav
#     - clip_0407.wav
#     - clip_0408.wav
#     - clip_0409.wav
#     - clip_0410.wav
#     - clip_0411.wav
#     - clip_0412.wav
#     - clip_0413.wav
#     - clip_0414.wav
#     - clip_0415.wav
#     - clip_0416.wav
#     - clip_0417.wav
#     - clip_0418.wav
#     - clip_0419.wav
#     - clip_0420.wav
#     - clip_0421.wav
#     - clip_0422.wav
#     - clip_0423.wav
#     - clip_0424.wav
#     - clip_0425.wav
#     - clip_0426.wav
#     - clip_0427.wav
#     - clip_0428.wav
#     - clip_0429.wav
#     - clip_0430.wav
#     - clip_0431.wav
#     - clip_0432.wav
#     - clip_0433.wav
#     - clip_0434.wav
#     - clip_0435.wav
#     - clip_0436.wav
#     - clip_0437.wav
#     - clip_0438.wav
#     - clip_0439.wav
#     - clip_0440.wav
#     - clip_0441.wav
#     - clip_0442.wav
#     - clip_0443.wav
#     - clip_0444.wav
#     - clip_0445.wav
#     - clip_0446.wav
#     - clip_0447.wav
#     - clip_0448.wav
#     - clip_0449.wav
#     - clip_0450.wav
#     - clip_0451.wav
#     - clip_0452.wav
#     - clip_0453.wav
#     - clip_0454.wav
#     - clip_0455.wav
#     - clip_0456.wav
#     - clip_0457.wav
#     - clip_0458.wav
#     - clip_0459.wav
#     - clip_0460.wav
#     - clip_0461.wav
#     - clip_0462.wav
#     - clip_0463.wav
#     - clip_0464.wav
#     - clip_0465.wav
#     - clip_0466.wav
#     - clip_0467.wav
#     - clip_0468.wav
#     - clip_0469.wav
#     - clip_0470.wav
#     - clip_0471.wav
#     - clip_0472.wav
#     - clip_0473.wav
#     - clip_0474.wav
#     - clip_0475.wav
#     - clip_0476.wav
#     - clip_0477.wav
#     - clip_0478.wav
#     - clip_0479.wav
#     - clip_0480.wav
#     - clip_0481.wav
#     - clip_0482.wav
#     - clip_0483.wav
#     - clip_0484.wav
#     - clip_0485.wav
#     - clip_0486.wav
#     - clip_0487.wav
#     - clip_0488.wav
#     - clip_0489.wav
#     - clip_0490.wav
#     - clip_0491.wav
#     - clip_0492.wav
#     - clip_0493.wav
#     - clip_0494.wav
#     - clip_0495.wav
#     - clip_0496.wav
#     - clip_0497.wav
#     - clip_0498.wav
#     - clip_0499.wav
#     - clip_0500.wav
#     - clip_0501.wav
#     - clip_0502.wav
#     - clip_0503.wav
#     - clip_0504.wav
#     - clip_0505.wav
#     - clip_0506.wav
#     - clip_0507.wav
#     - clip_0508.wav
#     - clip_0509.wav
#     - clip_0510.wav
#     - clip_0511.wav
#     - clip_0512.wav
#     - clip_0513.wav
#     - clip_0514.wav
#     - clip_0515.wav
#     - clip_0516.wav
#     - clip_0517.wav
#     - clip_0518.wav
#     - clip_0519.wav
#     - clip_0520.wav
#     - clip_0521.wav
#     - clip_0522.wav
#     - clip_0523.wav
#     - clip_0524.wav
#     - clip_0525.wav
#     - clip_0526.wav
#     - clip_0527.wav
#     - clip_0528.wav
#     - clip_0529.wav
#     - clip_0530.wav
#     - clip_0531.wav
#     - clip_0532.wav
#     - clip_0533.wav
#     - clip_0534.wav
#     - clip_0535.wav
#     - clip_0536.wav
#     - clip_0537.wav
#     - clip_0538.wav
#     - clip_0539.wav
#     - clip_0540.wav
#     - clip_0541.wav
#     - clip_0542.wav
#     - clip_0543.wav
#     - clip_0544.wav
#     - clip_0545.wav
#     - clip_0546.wav
#     - clip_0547.wav
#     - clip_0548.wav
#     - clip_0549.wav
#     - clip_0550.wav
#     - clip_0551.wav
#     - clip_0552.wav
#     - clip_0553.wav
#     - clip_0554.wav
#     - clip_0555.wav
#     - clip_0556.wav
#     - clip_0557.wav
#     - clip_0558.wav
#     - clip_0559.wav
#     - clip_0560.wav
#     - clip_0561.wav
#     - clip_0562.wav
#     - clip_0563.wav
#     - clip_0564.wav
#     - clip_0565.wav
#     - clip_0566.wav
#     - clip_0567.wav
#     - clip_0568.wav
#     - clip_0569.wav
#     - clip_0570.wav
#     - clip_0571.wav
#     - clip_0572.wav
#     - clip_0573.wav
#     - clip_0574.wav
#     - clip_0575.wav
#     - clip_0576.wav
#     - clip_0577.wav
#     - clip_0578.wav
#     - clip_0579.wav
#     - clip_0580.wav
#     - clip_0581.wav
#     - clip_0582.wav
#     - clip_0583.wav
#     - clip_0584.wav
#     - clip_0585.wav
#     - clip_0586.wav
#     - clip_0587.wav
#     - clip_0588.wav
#     - clip_0589.wav
#     - clip_0590.wav
#     - clip_0591.wav
#     - clip_0592.wav
#     - clip_0593.wav
#     - clip_0594.wav
#     - clip_0595.wav
#     - clip_0596.wav
#     - clip_0597.wav
#     - clip_0598.wav
#     - clip_0599.wav
#     - clip_0600.wav
#     - clip_0601.wav
#     - clip_0602.wav
#     - clip_0603.wav
#     - clip_0604.wav
#     - clip_0605.wav
#     - clip_0606.wav
#     - clip_0607.wav
#     - clip_0608.wav
#     - clip_0609.wav
#     - clip_0610.wav
#     - clip_0611.wav
#     - clip_0612.wav
#     - clip_0613.wav
#     - clip_0614.wav
#     - clip_0615.wav
#     - clip_0616.wav
#     - clip_0617.wav
#     - clip_0618.wav
#     - clip_0619.wav
#     - clip_0620.wav
#     - clip_0621.wav
#     - clip_0622.wav
#     - clip_0623.wav
#     - clip_0624.wav
#     - clip_0625.wav
#     - clip_0626.wav
#     - clip_0627.wav
#     - clip_0628.wav
#     - clip_0629.wav
#     - clip_0630.wav
#     - clip_0631.wav
#     - clip_0632.wav
#     - clip_0633.wav
#     - clip_0634.wav
#     - clip_0635.wav
#     - clip_0636.wav
#     - clip_0637.wav
#     - clip_0638.wav
#     - clip_0639.wav
#     - clip_0640.wav
#     - clip_0641.wav
#     - clip_0642.wav
#     - clip_0643.wav
#     - clip_0644.wav
#     - clip_0645.wav
#     - clip_0646.wav
#     - clip_0647.wav
#     - clip_0648.wav
#     - clip_0649.wav
#     - clip_0650.wav
#     - clip_0651.wav
#     - clip_0652.wav
#     - clip_0653.wav
#     - clip_0654.wav
#     - clip_0655.wav
#     - clip_0656.wav
#     - clip_0657.wav
#     - clip_0658.wav
#     - clip_0659.wav
#     - clip_0660.wav
#     - clip_0661.wav
#     - clip_0662.wav
#     - clip_0663.wav
#     - clip_0664.wav
#     - clip_0665.wav
#     - clip_0666.wav
#     - clip_0667.wav
#     - clip_0668.wav
#     - clip_0669.wav
#     - clip_0670.wav
#     - clip_0671.wav
#     - clip_0672.wav
#     - clip_0673.wav
#     - clip_0674.wav
#     - clip_0675.wav
#     - clip_0676.wav
#     - clip_0677.wav
#     - clip_0678.wav
#     - clip_0679.wav
#     - clip_0680.wav
#     - clip_0681.wav
#     - clip_0682.wav
#     - clip_0683.wav
#     - clip_0684.wav
#     - clip_0685.wav
#     - clip_0686.wav
#     - clip_0687.wav
#     - clip_0688.wav
#     - clip_0689.wav
#     - clip_0690.wav
#     - clip_0691.wav
#     - clip_0692.wav
#     - clip_0693.wav
#     - clip_0694.wav
#     - clip_0695.wav
#     - clip_0696.wav
#     - clip_0697.wav
#     - clip_0698.wav
#     - clip_0699.wav
#     - clip_0700.wav
#     - clip_0701.wav
#     - clip_0702.wav
#     - clip_0703.wav
#     - clip_0704.wav
#     - clip_0705.wav
#     - clip_0706.wav
#     - clip_0707.wav
#     - clip_0708.wav
#     - clip_0709.wav
#     - clip_0710.wav
#     - clip_0711.wav
#     - clip_0712.wav
#     - clip_0713.wav
#     - clip_0714.wav
#     - clip_0715.wav
#     - clip_0716.wav
#     - clip_0717.wav
#     - clip_0718.wav
#     - clip_0719.wav
#     - clip_0720.wav
#     - clip_0721.wav
#     - clip_0722.wav
#     - clip_0723.wav
#     - clip_0724.wav
#     - clip_0725.wav
#     - clip_0726.wav
#     - clip_0727.wav
#     - clip_0728.wav
#     - clip_0729.wav
#     - clip_0730.wav
#     - clip_0731.wav
#     - clip_0732.wav
#     - clip_0733.wav
#     - clip_0734.wav
#     - clip_0735.wav
#     - clip_0736.wav
#     - clip_0737.wav
#     - clip_0738.wav
#     - clip_0739.wav
#     - clip_0740.wav
#     - clip_0741.wav
#     - clip_0742.wav
#     - clip_0743.wav
#     - clip_0744.wav
#     - clip_0745.wav
#     - clip_0746.wav
#     - clip_0747.wav
#     - clip_0748.wav
#     - clip_0749.wav
#     - clip_0750.wav
#     - clip_0751.wav
#     - clip_0752.wav
#     - clip_0753.wav
#     - clip_0754.wav
#     - clip_0755.wav
#     - clip_0756.wav
#     - clip_0757.wav
#     - clip_0758.wav
#     - clip_0759.wav
#     - clip_0760.wav
#     - clip_0761.wav
#     - clip_0762.wav
#     - clip_0763.wav
#     - clip_0764.wav
#     - clip_0765.wav
#     - clip_0766.wav
#     - clip_0767.wav
#     - clip_0768.wav
#     - clip_0769.wav
#     - clip_0770.wav
#     - clip_0771.wav
#     - clip_0772.wav
#     - clip_0773.wav
#     - clip_0774.wav
#     - clip_0775.wav
#     - clip_0776.wav
#     - clip_0777.wav
#     - clip_0778.wav
#     - clip_0779.wav
#     - clip_0780.wav
#     - clip_0781.wav
#     - clip_0782.wav
#     - clip_0783.wav
#     - clip_0784.wav
#     - clip_0785.wav
#     - clip_0786.wav
#     - clip_0787.wav
#     - clip_0788.wav
#     - clip_0789.wav
#     - clip_0790.wav
#     - clip_0791.wav
#     - clip_0792.wav
#     - clip_0793.wav
#     - clip_0794.wav
#     - clip_0795.wav
#     - clip_0796.wav
#     - clip_0797.wav
#     - clip_0798.wav
#     - clip_0799.wav
#     - clip_0800.wav
#     - clip_0801.wav
#     - clip_0802.wav
#     - clip_0803.wav
#     - clip_0804.wav
#     - clip_0805.wav
#     - clip_0806.wav
#     - clip_0807.wav
#     - clip_0808.wav
#     - clip_0809.wav
#     - clip_0810.wav
#     - clip_0811.wav
#     - clip_0812.wav
#     - clip_0813.wav
#     - clip_0814.wav
#     - clip_0815.wav
#     - clip_0816.wav
#     - clip_0817.wav
#     - clip_0818.wav
#     - clip_0819.wav
#     - clip_0820.wav
#     - clip_0821.wav
#     - clip_0822.wav
#     - clip_0823.wav
#     - clip_0824.wav
#     - clip_0825.wav
#     - clip_0826.wav
#     - clip_0827.wav
#     - clip_0828.wav
#     - clip_0829.wav
#     - clip_0830.wav
#     - clip_0831.wav
#     - clip_0832.wav
#     - clip_0833.wav
#     - clip_0834.wav
#     - clip_0835.wav
#     - clip_0836.wav
#     - clip_0837.wav
#     - clip_0838.wav
#     - clip_0839.wav
#     - clip_0840.wav
#     - clip_0841.wav
#     - clip_0842.wav
#     - clip_0843.wav
#     - clip_0844.wav
#     - clip_0845.wav
#     - clip_0846.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_19
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
#     - clip_0078.wav
#     - clip_0079.wav
#     - clip_0080.wav
#     - clip_0081.wav
#     - clip_0082.wav
#     - clip_0083.wav
#     - clip_0084.wav
#     - clip_0085.wav
#     - clip_0086.wav
#     - clip_0087.wav
#     - clip_0088.wav
#     - clip_0089.wav
#     - clip_0090.wav
#     - clip_0091.wav
#     - clip_0092.wav
#     - clip_0093.wav
#     - clip_0094.wav
#     - clip_0095.wav
#     - clip_0096.wav
#     - clip_0097.wav
#     - clip_0098.wav
#     - clip_0099.wav
#     - clip_0100.wav
#     - clip_0101.wav
#     - clip_0102.wav
#     - clip_0103.wav
#     - clip_0104.wav
#     - clip_0105.wav
#     - clip_0106.wav
#     - clip_0107.wav
#     - clip_0108.wav
#     - clip_0109.wav
#     - clip_0110.wav
#     - clip_0111.wav
#     - clip_0112.wav
#     - clip_0113.wav
#     - clip_0114.wav
#     - clip_0115.wav
#     - clip_0116.wav
#     - clip_0117.wav
#     - clip_0118.wav
#     - clip_0119.wav
#     - clip_0120.wav
#     - clip_0121.wav
#     - clip_0122.wav
#     - clip_0123.wav
#     - clip_0124.wav
#     - clip_0125.wav
#     - clip_0126.wav
#     - clip_0127.wav
#     - clip_0128.wav
#     - clip_0129.wav
#     - clip_0130.wav
#     - clip_0131.wav
#     - clip_0132.wav
#     - clip_0133.wav
#     - clip_0134.wav
#     - clip_0135.wav
#     - clip_0136.wav
#     - clip_0137.wav
#     - clip_0138.wav
#     - clip_0139.wav
#     - clip_0140.wav
#     - clip_0141.wav
#     - clip_0142.wav
#     - clip_0143.wav
#     - clip_0144.wav
#     - clip_0145.wav
#     - clip_0146.wav
#     - clip_0147.wav
#     - clip_0148.wav
#     - clip_0149.wav
#     - clip_0150.wav
#     - clip_0151.wav
#     - clip_0152.wav
#     - clip_0153.wav
#     - clip_0154.wav
#     - clip_0155.wav
#     - clip_0156.wav
#     - clip_0157.wav
#     - clip_0158.wav
#     - clip_0159.wav
#     - clip_0160.wav
#     - clip_0161.wav
#     - clip_0162.wav
#     - clip_0163.wav
#     - clip_0164.wav
#     - clip_0165.wav
#     - clip_0166.wav
#     - clip_0167.wav
#     - clip_0168.wav
#     - clip_0169.wav
#     - clip_0170.wav
#     - clip_0171.wav
#     - clip_0172.wav
#     - clip_0173.wav
#     - clip_0174.wav
#     - clip_0175.wav
#     - clip_0176.wav
#     - clip_0177.wav
#     - clip_0178.wav
#     - clip_0179.wav
#     - clip_0180.wav
#     - clip_0181.wav
#     - clip_0182.wav
#     - clip_0183.wav
#     - clip_0184.wav
#     - clip_0185.wav
#     - clip_0186.wav
#     - clip_0187.wav
#     - clip_0188.wav
#     - clip_0189.wav
#     - clip_0190.wav
#     - clip_0191.wav
#     - clip_0192.wav
#     - clip_0193.wav
#     - clip_0194.wav
#     - clip_0195.wav
#     - clip_0196.wav
#     - clip_0197.wav
#     - clip_0198.wav
#     - clip_0199.wav
#     - clip_0200.wav
#     - clip_0201.wav
#     - clip_0202.wav
#     - clip_0203.wav
#     - clip_0204.wav
#     - clip_0205.wav
#     - clip_0206.wav
#     - clip_0207.wav
#     - clip_0208.wav
#     - clip_0209.wav
#     - clip_0210.wav
#     - clip_0211.wav
#     - clip_0212.wav
#     - clip_0213.wav
#     - clip_0214.wav
#     - clip_0215.wav
#     - clip_0216.wav
#     - clip_0217.wav
#     - clip_0218.wav
#     - clip_0219.wav
#     - clip_0220.wav
#     - clip_0221.wav
#     - clip_0222.wav
#     - clip_0223.wav
#     - clip_0224.wav
#     - clip_0225.wav
#     - clip_0226.wav
#     - clip_0227.wav
#     - clip_0228.wav
#     - clip_0229.wav
#     - clip_0230.wav
#     - clip_0231.wav
#     - clip_0232.wav
#     - clip_0233.wav
#     - clip_0234.wav
#     - clip_0235.wav
#     - clip_0236.wav
#     - clip_0237.wav
#     - clip_0238.wav
#     - clip_0239.wav
#     - clip_0240.wav
#     - clip_0241.wav
#     - clip_0242.wav
#     - clip_0243.wav
#     - clip_0244.wav
#     - clip_0245.wav
#     - clip_0246.wav
#     - clip_0247.wav
#     - clip_0248.wav
#     - clip_0249.wav
#     - clip_0250.wav
#     - clip_0251.wav
#     - clip_0252.wav
#     - clip_0253.wav
#     - clip_0254.wav
#     - clip_0255.wav
#     - clip_0256.wav
#     - clip_0257.wav
#     - clip_0258.wav
#     - clip_0259.wav
#     - clip_0260.wav
#     - clip_0261.wav
#     - clip_0262.wav
#     - clip_0263.wav
#     - clip_0264.wav
#     - clip_0265.wav
#     - clip_0266.wav
#     - clip_0267.wav
#     - clip_0268.wav
#     - clip_0269.wav
#     - clip_0270.wav
#     - clip_0271.wav
#     - clip_0272.wav
#     - clip_0273.wav
#     - clip_0274.wav
#     - clip_0275.wav
#     - clip_0276.wav
#     - clip_0277.wav
#     - clip_0278.wav
#     - clip_0279.wav
#     - clip_0280.wav
#     - clip_0281.wav
#     - clip_0282.wav
#     - clip_0283.wav
#     - clip_0284.wav
#     - clip_0285.wav
#     - clip_0286.wav
#     - clip_0287.wav
#     - clip_0288.wav
#     - clip_0289.wav
#     - clip_0290.wav
#     - clip_0291.wav
#     - clip_0292.wav
#     - clip_0293.wav
#     - clip_0294.wav
#     - clip_0295.wav
#     - clip_0296.wav
#     - clip_0297.wav
#     - clip_0298.wav
#     - clip_0299.wav
#     - clip_0300.wav
#     - clip_0301.wav
#     - clip_0302.wav
#     - clip_0303.wav
#     - clip_0304.wav
#     - clip_0305.wav
#     - clip_0306.wav
#     - clip_0307.wav
#     - clip_0308.wav
#     - clip_0309.wav
#     - clip_0310.wav
#     - clip_0311.wav
#     - clip_0312.wav
#     - clip_0313.wav
#     - clip_0314.wav
#     - clip_0315.wav
#     - clip_0316.wav
#     - clip_0317.wav
#     - clip_0318.wav
#     - clip_0319.wav
#     - clip_0320.wav
#     - clip_0321.wav
#     - clip_0322.wav
#     - clip_0323.wav
#     - clip_0324.wav
#     - clip_0325.wav
#     - clip_0326.wav
#     - clip_0327.wav
#     - clip_0328.wav
#     - clip_0329.wav
#     - clip_0330.wav
#     - clip_0331.wav
#     - clip_0332.wav
#     - clip_0333.wav
#     - clip_0334.wav
#     - clip_0335.wav
#     - clip_0336.wav
#     - clip_0337.wav
#     - clip_0338.wav
#     - clip_0339.wav
#     - clip_0340.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_16
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_11
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_5
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_8
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
#     - clip_0078.wav
#     - clip_0079.wav
#     - clip_0080.wav
#     - clip_0081.wav
#     - clip_0082.wav
#     - clip_0083.wav
#     - clip_0084.wav
#     - clip_0085.wav
#     - clip_0086.wav
#     - clip_0087.wav
#     - clip_0088.wav
#     - clip_0089.wav
#     - clip_0090.wav
#     - clip_0091.wav
#     - clip_0092.wav
#     - clip_0093.wav
#     - clip_0094.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_14
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_13
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_7
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
#     - clip_0078.wav
#     - clip_0079.wav
#     - clip_0080.wav
#     - clip_0081.wav
#     - clip_0082.wav
#     - clip_0083.wav
#     - clip_0084.wav
#     - clip_0085.wav
#     - clip_0086.wav
#     - clip_0087.wav
#     - clip_0088.wav
#     - clip_0089.wav
#     - clip_0090.wav
#     - clip_0091.wav
#     - clip_0092.wav
#     - clip_0093.wav
#     - clip_0094.wav
#     - clip_0095.wav
#     - clip_0096.wav
#     - clip_0097.wav
#     - clip_0098.wav
#     - clip_0099.wav
#     - clip_0100.wav
#     - clip_0101.wav
#     - clip_0102.wav
#     - clip_0103.wav
#     - clip_0104.wav
#     - clip_0105.wav
#     - clip_0106.wav
#     - clip_0107.wav
#     - clip_0108.wav
#     - clip_0109.wav
#     - clip_0110.wav
#     - clip_0111.wav
#     - clip_0112.wav
#     - clip_0113.wav
#     - clip_0114.wav
#     - clip_0115.wav
#     - clip_0116.wav
#     - clip_0117.wav
#     - clip_0118.wav
#     - clip_0119.wav
#     - clip_0120.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_4
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_10
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_12
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
#     - clip_0078.wav
#     - clip_0079.wav
#     - clip_0080.wav
#     - clip_0081.wav
#     - clip_0082.wav
#     - clip_0083.wav
#     - clip_0084.wav
#     - clip_0085.wav
#     - clip_0086.wav
#     - clip_0087.wav
#     - clip_0088.wav
#     - clip_0089.wav
#     - clip_0090.wav
#     - clip_0091.wav
#     - clip_0092.wav
#     - clip_0093.wav
#     - clip_0094.wav
#     - clip_0095.wav
#     - clip_0096.wav
#     - clip_0097.wav
#     - clip_0098.wav
#     - clip_0099.wav
#     - clip_0100.wav
#     - clip_0101.wav
#     - clip_0102.wav
#     - clip_0103.wav
#     - clip_0104.wav
#     - clip_0105.wav
#     - clip_0106.wav
#     - clip_0107.wav
#     - clip_0108.wav
#     - clip_0109.wav
#     - clip_0110.wav
#     - clip_0111.wav
#     - clip_0112.wav
#     - clip_0113.wav
#     - clip_0114.wav
#     - clip_0115.wav
#     - clip_0116.wav
#     - clip_0117.wav
#     - clip_0118.wav
#     - clip_0119.wav
#     - clip_0120.wav
#     - clip_0121.wav
#     - clip_0122.wav
#     - clip_0123.wav
#     - clip_0124.wav
#     - clip_0125.wav
#     - clip_0126.wav
#     - clip_0127.wav
#     - clip_0128.wav
#     - clip_0129.wav
#     - clip_0130.wav
#     - clip_0131.wav
#     - clip_0132.wav
#     - clip_0133.wav
#     - clip_0134.wav
#     - clip_0135.wav
#     - clip_0136.wav
#     - clip_0137.wav
#     - clip_0138.wav
#     - clip_0139.wav
#     - clip_0140.wav
#     - clip_0141.wav
#     - clip_0142.wav
#     - clip_0143.wav
#     - clip_0144.wav
#     - clip_0145.wav
#     - clip_0146.wav
#     - clip_0147.wav
#     - clip_0148.wav
#     - clip_0149.wav
#     - clip_0150.wav
#     - clip_0151.wav
#     - clip_0152.wav
#     - clip_0153.wav
#     - clip_0154.wav
#     - clip_0155.wav
#     - clip_0156.wav
#     - clip_0157.wav
#     - clip_0158.wav
#     - clip_0159.wav
#     - clip_0160.wav
#     - clip_0161.wav
#     - clip_0162.wav
#     - clip_0163.wav
#     - clip_0164.wav
#     - clip_0165.wav
#     - clip_0166.wav
#     - clip_0167.wav
#     - clip_0168.wav
#     - clip_0169.wav
#     - clip_0170.wav
#     - clip_0171.wav
#     - clip_0172.wav
#     - clip_0173.wav
#     - clip_0174.wav
#     - clip_0175.wav
#     - clip_0176.wav
#     - clip_0177.wav
#     - clip_0178.wav
#     - clip_0179.wav
#     - clip_0180.wav
#     - clip_0181.wav
#     - clip_0182.wav
#     - clip_0183.wav
#     - clip_0184.wav
#     - clip_0185.wav
#     - clip_0186.wav
#     - clip_0187.wav
#     - clip_0188.wav
#     - clip_0189.wav
#     - clip_0190.wav
#     - clip_0191.wav
#     - clip_0192.wav
#     - clip_0193.wav
#     - clip_0194.wav
#     - clip_0195.wav
#     - clip_0196.wav
#     - clip_0197.wav
#     - clip_0198.wav
#     - clip_0199.wav
#     - clip_0200.wav
#     - clip_0201.wav
#     - clip_0202.wav
#     - clip_0203.wav
#     - clip_0204.wav
#     - clip_0205.wav
#     - clip_0206.wav
#     - clip_0207.wav
#     - clip_0208.wav
#     - clip_0209.wav
#     - clip_0210.wav
#     - clip_0211.wav
#     - clip_0212.wav
#     - clip_0213.wav
#     - clip_0214.wav
#     - clip_0215.wav
#     - clip_0216.wav
#     - clip_0217.wav
#     - clip_0218.wav
#     - clip_0219.wav
#     - clip_0220.wav
#     - clip_0221.wav
#     - clip_0222.wav
#     - clip_0223.wav
#     - clip_0224.wav
#     - clip_0225.wav
#     - clip_0226.wav
#     - clip_0227.wav
#     - clip_0228.wav
#     - clip_0229.wav
#     - clip_0230.wav
#     - clip_0231.wav
#     - clip_0232.wav
#     - clip_0233.wav
#     - clip_0234.wav
#     - clip_0235.wav
#     - clip_0236.wav
#     - clip_0237.wav
#     - clip_0238.wav
#     - clip_0239.wav
#     - clip_0240.wav
#     - clip_0241.wav
#     - clip_0242.wav
#     - clip_0243.wav
#     - clip_0244.wav
#     - clip_0245.wav
#     - clip_0246.wav
#     - clip_0247.wav
#     - clip_0248.wav
#     - clip_0249.wav
#     - clip_0250.wav
#     - clip_0251.wav
#     - clip_0252.wav
#     - clip_0253.wav
#     - clip_0254.wav
#     - clip_0255.wav
#     - clip_0256.wav
#     - clip_0257.wav
#     - clip_0258.wav
#     - clip_0259.wav
#     - clip_0260.wav
#     - clip_0261.wav
#     - clip_0262.wav
#     - clip_0263.wav
#     - clip_0264.wav
#     - clip_0265.wav
#     - clip_0266.wav
#     - clip_0267.wav
#     - clip_0268.wav
#     - clip_0269.wav
#     - clip_0270.wav
#     - clip_0271.wav
#     - clip_0272.wav
#     - clip_0273.wav
#     - clip_0274.wav
#     - clip_0275.wav
#     - clip_0276.wav
#     - clip_0277.wav
#     - clip_0278.wav
#     - clip_0279.wav
#     - clip_0280.wav
#     - clip_0281.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_17
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
#     - clip_0078.wav
#     - clip_0079.wav
#     - clip_0080.wav
#     - clip_0081.wav
#     - clip_0082.wav
#     - clip_0083.wav
#     - clip_0084.wav
#     - clip_0085.wav
#     - clip_0086.wav
#     - clip_0087.wav
#     - clip_0088.wav
#     - clip_0089.wav
#     - clip_0090.wav
#     - clip_0091.wav
#     - clip_0092.wav
#     - clip_0093.wav
#     - clip_0094.wav
#     - clip_0095.wav
#     - clip_0096.wav
#     - clip_0097.wav
#     - clip_0098.wav
#     - clip_0099.wav
#     - clip_0100.wav
#     - clip_0101.wav
#     - clip_0102.wav
#     - clip_0103.wav
#     - clip_0104.wav
#     - clip_0105.wav
#     - clip_0106.wav
#     - clip_0107.wav
#     - clip_0108.wav
#     - clip_0109.wav
#     - clip_0110.wav
#     - clip_0111.wav
#     - clip_0112.wav
#     - clip_0113.wav
#     - clip_0114.wav
#     - clip_0115.wav
#     - clip_0116.wav
#     - clip_0117.wav
#     - clip_0118.wav
#     - clip_0119.wav
#     - clip_0120.wav
#     - clip_0121.wav
#     - clip_0122.wav
#     - clip_0123.wav
#     - clip_0124.wav
#     - clip_0125.wav
#     - clip_0126.wav
#     - clip_0127.wav
#     - clip_0128.wav
#     - clip_0129.wav
#     - clip_0130.wav
#     - clip_0131.wav
#     - clip_0132.wav
#     - clip_0133.wav
#     - clip_0134.wav
#     - clip_0135.wav
#     - clip_0136.wav
#     - clip_0137.wav
#     - clip_0138.wav
#     - clip_0139.wav
#     - clip_0140.wav
#     - clip_0141.wav
#     - clip_0142.wav
#     - clip_0143.wav
#     - clip_0144.wav
#     - clip_0145.wav
#     - clip_0146.wav
#     - clip_0147.wav
#     - clip_0148.wav
#     - clip_0149.wav
#     - clip_0150.wav
#     - clip_0151.wav
#     - clip_0152.wav
#     - clip_0153.wav
#     - clip_0154.wav
#     - clip_0155.wav
#     - clip_0156.wav
#     - clip_0157.wav
#     - clip_0158.wav
#     - clip_0159.wav
#     - clip_0160.wav
#     - clip_0161.wav
#     - clip_0162.wav
#     - clip_0163.wav
#     - clip_0164.wav
#     - clip_0165.wav
#     - clip_0166.wav
#     - clip_0167.wav
#     - clip_0168.wav
#     - clip_0169.wav
#     - clip_0170.wav
#     - clip_0171.wav
#     - clip_0172.wav
#     - clip_0173.wav
#     - clip_0174.wav
#     - clip_0175.wav
#     - clip_0176.wav
#     - clip_0177.wav
#     - clip_0178.wav
#     - clip_0179.wav
#     - clip_0180.wav
#     - clip_0181.wav
#     - clip_0182.wav
#     - clip_0183.wav
#     - clip_0184.wav
#     - clip_0185.wav
#     - clip_0186.wav
#     - clip_0187.wav
#     - clip_0188.wav
#     - clip_0189.wav
#     - clip_0190.wav
#     - clip_0191.wav
#     - clip_0192.wav
#     - clip_0193.wav
#     - clip_0194.wav
#     - clip_0195.wav
#     - clip_0196.wav
#     - clip_0197.wav
#     - clip_0198.wav
#     - clip_0199.wav
#     - clip_0200.wav
#     - clip_0201.wav
#     - clip_0202.wav
#     - clip_0203.wav
#     - clip_0204.wav
#     - clip_0205.wav
#     - clip_0206.wav
#     - clip_0207.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_15
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
#     - clip_0078.wav
#     - clip_0079.wav
#     - clip_0080.wav
#     - clip_0081.wav
#     - clip_0082.wav
#     - clip_0083.wav
#     - clip_0084.wav
#     - clip_0085.wav
#     - clip_0086.wav
#     - clip_0087.wav
#     - clip_0088.wav
#     - clip_0089.wav
#     - clip_0090.wav
#     - clip_0091.wav
#     - clip_0092.wav
#     - clip_0093.wav
#     - clip_0094.wav
#     - clip_0095.wav
#     - clip_0096.wav
#     - clip_0097.wav
#     - clip_0098.wav
#     - clip_0099.wav
#     - clip_0100.wav
#     - clip_0101.wav
#     - clip_0102.wav
#     - clip_0103.wav
#     - clip_0104.wav
#     - clip_0105.wav
#     - clip_0106.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_9
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav
#     - clip_0025.wav
#     - clip_0026.wav
#     - clip_0027.wav
#     - clip_0028.wav
#     - clip_0029.wav
#     - clip_0030.wav
#     - clip_0031.wav
#     - clip_0032.wav
#     - clip_0033.wav
#     - clip_0034.wav
#     - clip_0035.wav
#     - clip_0036.wav
#     - clip_0037.wav
#     - clip_0038.wav
#     - clip_0039.wav
#     - clip_0040.wav
#     - clip_0041.wav
#     - clip_0042.wav
#     - clip_0043.wav
#     - clip_0044.wav
#     - clip_0045.wav
#     - clip_0046.wav
#     - clip_0047.wav
#     - clip_0048.wav
#     - clip_0049.wav
#     - clip_0050.wav
#     - clip_0051.wav
#     - clip_0052.wav
#     - clip_0053.wav
#     - clip_0054.wav
#     - clip_0055.wav
#     - clip_0056.wav
#     - clip_0057.wav
#     - clip_0058.wav
#     - clip_0059.wav
#     - clip_0060.wav
#     - clip_0061.wav
#     - clip_0062.wav
#     - clip_0063.wav
#     - clip_0064.wav
#     - clip_0065.wav
#     - clip_0066.wav
#     - clip_0067.wav
#     - clip_0068.wav
#     - clip_0069.wav
#     - clip_0070.wav
#     - clip_0071.wav
#     - clip_0072.wav
#     - clip_0073.wav
#     - clip_0074.wav
#     - clip_0075.wav
#     - clip_0076.wav
#     - clip_0077.wav
# 📁 Folder: /content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset/Recording_6
#     - clip_0000.wav
#     - clip_0001.wav
#     - clip_0002.wav
#     - clip_0003.wav
#     - clip_0004.wav
#     - clip_0005.wav
#     - clip_0006.wav
#     - clip_0007.wav
#     - clip_0008.wav
#     - clip_0009.wav
#     - clip_0010.wav
#     - clip_0011.wav
#     - clip_0012.wav
#     - clip_0013.wav
#     - clip_0014.wav
#     - clip_0015.wav
#     - clip_0016.wav
#     - clip_0017.wav
#     - clip_0018.wav
#     - clip_0019.wav
#     - clip_0020.wav
#     - clip_0021.wav
#     - clip_0022.wav
#     - clip_0023.wav
#     - clip_0024.wav

# %%
# !find /content/drive/MyDrive/Audio\ Dataset\ CSE400/1sec_dataset -name "*.wav" | wc -l
# Out:
# 2284

# %%
# Count in Audio Dataset CSE400
# !find "/content/drive/MyDrive/Audio Dataset CSE400" -name "*.wav" | wc -l

# Count in Normal Child
# !find "/content/drive/MyDrive/Normal Child" -name "*.wav" | wc -l
# Out:
# 2746
# 1463

# %%
from pydub import AudioSegment
import os

normal_input_folder = '/content/drive/MyDrive/Normal Child'
normal_output_folder = '/content/drive/MyDrive/Normal Child/1sec_dataset'
os.makedirs(normal_output_folder, exist_ok=True)

chunk_length_ms = 1 * 1000  # 1 second

for filename in os.listdir(normal_input_folder):
    if filename.endswith(".m4a"):
        audio_path = os.path.join(normal_input_folder, filename)
        audio = AudioSegment.from_file(audio_path, format="m4a")

        base_name = os.path.splitext(filename)[0]
        output_folder = os.path.join(normal_output_folder, base_name)
        os.makedirs(output_folder, exist_ok=True)

        for i, chunk_start in enumerate(range(0, len(audio), chunk_length_ms)):
            chunk = audio[chunk_start:chunk_start + chunk_length_ms]
            chunk.export(f"{output_folder}/clip_{i:04d}.wav", format="wav")

        print(f"✅ Normal child audio split: {filename}")
# Out:
# ✅ Normal child audio split: Recording_28.m4a
# ✅ Normal child audio split: Recording_23.m4a
# ✅ Normal child audio split: Recording_30.m4a
# ✅ Normal child audio split: Recording_27.m4a
# ✅ Normal child audio split: Recording_29.m4a
# ✅ Normal child audio split: Recording_26.m4a
# ✅ Normal child audio split: Recording_25.m4a
# ✅ Normal child audio split: Recording_24.m4a
# ✅ Normal child audio split: Recording_21.m4a
# ✅ Normal child audio split: Recording_22.m4a

# %%
# !find "/content/drive/MyDrive/Normal Child/1sec_dataset" -name "*.wav" | wc -l
# Out:
# 1463

# %%
import csv
import os

base_folders = {
    'autistic': '/content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset',
    'non_autistic': '/content/drive/MyDrive/Normal Child/1sec_dataset'
}

metadata_path = '/content/drive/MyDrive/combined_metadata.csv'

with open(metadata_path, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['filepath', 'label'])

    for label, base_folder in base_folders.items():
        for root, _, files in os.walk(base_folder):
            for file in files:
                if file.endswith('.wav'):
                    filepath = os.path.join(root, file)
                    writer.writerow([filepath, label])

print(f"✅ Metadata CSV saved at: {metadata_path}")
# Out:
# ✅ Metadata CSV saved at: /content/drive/MyDrive/combined_metadata.csv

# %%
import os

def count_clips(folder):
    count = 0
    for root, _, files in os.walk(folder):
        count += sum(1 for file in files if file.endswith('.wav'))
    return count

autistic_folder = '/content/drive/MyDrive/Audio Dataset CSE400/1sec_dataset'
non_autistic_folder = '/content/drive/MyDrive/Normal Child/1sec_dataset'

print("Autistic clips:", count_clips(autistic_folder))
print("Non-autistic clips:", count_clips(non_autistic_folder))
# Out:
# Autistic clips: 2284
# Non-autistic clips: 1463

# %%
from pydub import AudioSegment
import os

input_folder = '/content/drive/MyDrive/Audio Dataset CSE400'
output_folder = os.path.join(input_folder, '1sec_dataset')  # updated folder name
os.makedirs(output_folder, exist_ok=True)

# Loop through all .m4a files
for filename in os.listdir(input_folder):
    if filename.endswith(".m4a"):
        audio_path = os.path.join(input_folder, filename)
        audio = AudioSegment.from_file(audio_path, format="m4a")

        chunk_length_ms = 1 * 1000  # ✅ 1 second

        # Create a subfolder for each audio file
        base_name = os.path.splitext(filename)[0]
        file_output_folder = os.path.join(output_folder, base_name)
        os.makedirs(file_output_folder, exist_ok=True)

        # Split into 1-second chunks
        for i, chunk_start in enumerate(range(0, len(audio), chunk_length_ms)):
            chunk = audio[chunk_start:chunk_start + chunk_length_ms]
            chunk.export(f"{file_output_folder}/clip_{i:04d}.wav", format="wav")

        print(f"✅ Done splitting: {filename}")
# Out:
# ✅ Done splitting: Recording_18.m4a
# ✅ Done splitting: Recording_19.m4a
# ✅ Done splitting: Recording_16.m4a
# ✅ Done splitting: Recording_11.m4a
# ✅ Done splitting: Recording_5.m4a
# ✅ Done splitting: Recording_8.m4a
# ✅ Done splitting: Recording_14.m4a
# ✅ Done splitting: Recording_13.m4a
# ✅ Done splitting: Recording_7.m4a
# ✅ Done splitting: Recording_4.m4a
# ✅ Done splitting: Recording_10.m4a
# ✅ Done splitting: Recording_12.m4a
# ✅ Done splitting: Recording_17.m4a
# ✅ Done splitting: Recording_15.m4a
# ✅ Done splitting: Recording_9.m4a
# ✅ Done splitting: Recording_6.m4a
